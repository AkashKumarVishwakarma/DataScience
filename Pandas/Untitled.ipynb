# %%
import pandas as pd

data = {
    "Rank": list(range(1, 51)),
    "Title": [
        "Fullmetal Alchemist: Brotherhood(64 eps)", "Steins;Gate(12 eps)", "Attack on Titan Final Season(12 eps)",
        "Death Note(12 eps)", "Hunter x Hunter(12 eps)", "Gintama(12 eps)", "Code Geass(12 eps)",
        "Naruto Shippuden(12 eps)", "One Piece(12 eps)", "Demon Slayer(12 eps)",
        "Jujutsu Kaisen(12 eps)", "My Hero Academia(12 eps)", "Tokyo Ghoul(12 eps)",
        "Black Clover(12 eps)", "Bleach(12 eps)", "Dragon Ball Z(12 eps)",
        "Spy x Family(12 eps)", "Vinland Saga(12 eps)", "Monster(12 eps)", "Cowboy Bebop(12 eps)",
        "Haikyuu!!(16 eps)", "Mob Psycho 100(16 eps)", "Re:Zero(16 eps)", "Fate Zero(16 eps)",
        "Parasyte(16 eps)", "Erased(16 eps)", "Your Lie in April(16 eps)", "Clannad After Story(16 eps)",
        "Toradora!(16 eps)", "Angel Beats!(16 eps)", "No Game No Life(16 eps)", "Dr. Stone(16 eps)",
        "Fire Force(16 eps)", "Blue Lock(16 eps)", "Chainsaw Man(16 eps)", "Hellsing Ultimate(16 eps)",
        "The Promised Neverland(16 eps)", "Made in Abyss(16 eps)", "Psycho-Pass(16 eps)",
        "Akame ga Kill!", "Bungo Stray Dogs", "Kaguya-sama: Love is War",
        "Horimiya", "The Rising of the Shield Hero", "Overlord",
        "Mushoku Tensei(16 eps)", "Solo Leveling(16 eps)", "Frieren: Beyond Journey's End(16 eps)",
        "Oshi no Ko(16 eps)", "Kaiju No. 8(16 eps)"
    ],
    "Score": [
        9.10, 9.05, 9.03, 8.95, 9.02, 8.98, 8.91, 8.85, 8.92, 8.80,
        8.79, 8.50, 8.45, 8.40, 8.55, 8.70, 8.65, 8.88, 8.87, 8.75,
        8.82, 8.81, 8.60, 8.68, 8.58, 8.54, 8.66, 8.93, 8.30, 8.25,
        8.35, 8.32, 7.95, 8.20, 8.55, 8.42, 8.50, 8.71, 8.40, 7.90,
        8.28, 8.84, 8.22, 8.05, 8.15, 8.73, 8.78, 9.15, 8.76, 8.18
    ]
}

df = pd.DataFrame(data)

df.to_csv("anime.csv", index=False)

print("anime.csv file created!")
print(df.head())
# Out:
# anime.csv file created!
#    Rank                                     Title  Score
# 0     1  Fullmetal Alchemist: Brotherhood(64 eps)   9.10
# 1     2                       Steins;Gate(12 eps)   9.05
# 2     3      Attack on Titan Final Season(12 eps)   9.03
# 3     4                        Death Note(12 eps)   8.95
# 4     5                   Hunter x Hunter(12 eps)   9.02

# %%
import os

print(os.getcwd())      # current folder
print(os.listdir())     # folder ki files
# Out:
# C:\Users\DELL\OneDrive\Desktop\DataScience\Pandas
# ['.ipynb_checkpoints', 'anaconda_projects', 'anime.csv', 'DataFrames.ipynb', 'FeatureExtraction.ipynb', 'GroupByAggregation.ipynb', 'MergingJoiningConcatination.ipynb', 'MissingData.ipynb', 'Operations.ipynb', 'PivotTables.ipynb', 'Series.ipynb', 'Untitled.ipynb']
