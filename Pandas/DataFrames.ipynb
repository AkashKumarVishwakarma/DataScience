# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a DataFrame

# %%
data = {
    "Name":['John','Anna','Peter','Linda'],
    "Age":[20,34,29,42],
    "City":['New York', "paris", "Berlin", "London"],
    "Salary":[65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   20  New York   65000
# 1   Anna   34     paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John','Anna','Peter','Linda'],
    [20,34,29,42],
    ['New York', "paris", "Berlin", "London"],
    [65000, 70000, 62000, 85000]
]
df2 = pd.DataFrame(data_list).T
df2
# Out:
#        0   1         2      3
# 0   John  20  New York  65000
# 1   Anna  34     paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ["Name","Age","City","Salary"]
# df2 = pd.DataFrame(data_list, columns= columns).T
df2.columns = columns

# %%
df2
# Out:
#     Name Age      City Salary
# 0   John  20  New York  65000
# 1   Anna  34     paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %% [markdown]
# Selections and Indexing of Columns

# %%
# df2['Name']
df2['City']
# Out:
# 0    New York
# 1       paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new Column

# %%
df2["Designation"] = ["Doctor","Eng.","Doctor","Eng."]

# %%
df2
# Out:
#     Name Age      City Salary Designation
# 0   John  20  New York  65000      Doctor
# 1   Anna  34     paris  70000        Eng.
# 2  Peter  29    Berlin  62000      Doctor
# 3  Linda  42    London  85000        Eng.

# %% [markdown]
# Removing Column

# %%
df2.drop('Designation',axis = 1)
# Out:
#     Name Age      City Salary
# 0   John  20  New York  65000
# 1   Anna  34     paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df2
# Out:
#     Name Age      City Salary Designation
# 0   John  20  New York  65000      Doctor
# 1   Anna  34     paris  70000        Eng.
# 2  Peter  29    Berlin  62000      Doctor
# 3  Linda  42    London  85000        Eng.

# %%
df2.drop("Designation", axis=1, inplace=True)
df2
# Out:
#     Name Age      City Salary
# 0   John  20  New York  65000
# 1   Anna  34     paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df2.drop(["City","Salary"], axis=1, inplace=True)

# %%
df2
# Out:
#     Name Age
# 0   John  20
# 1   Anna  34
# 2  Peter  29
# 3  Linda  42

# %%
df2.drop(0,axis=0)
# Out:
#     Name Age
# 1   Anna  34
# 2  Peter  29
# 3  Linda  42

# %% [markdown]
# Selecting Rows

# %%
df2
# Out:
#     Name Age      City Salary
# 0   John  20  New York  65000
# 1   Anna  34     paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             20
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name Age      City Salary
# 0  John  20  New York  65000
# 1  Anna  34     paris  70000

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     paris   70000

# %%
df.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
df2
# Out:
#     Name Age      City Salary
# 0   John  20  New York  65000
# 1   Anna  34     paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
#I only want to see those people whose age is above 30
df2[df2["Age"] > 30]
# Out:
#     Name Age    City Salary
# 1   Anna  34   paris  70000
# 3  Linda  42  London  85000

# %%
# I only want people whose age is above 30 and their city must be peris.
df2[(df2["Age"]>30) & (df2["City"] == "paris")]
# Out:
#    Name Age   City Salary
# 1  Anna  34  paris  70000
